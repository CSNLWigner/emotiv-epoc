# %%
## Record data
import sys
sys.path.append('../')
from emokit_controller import EmokitController

# %%
import pickle
sess_data = pickle.load(open('../data.pkl','rb'))

# %%
import matplotlib.pyplot as plt
plt.plot(sess_data['AF4'])
plt.plot(sess_data['AF3'])
plt.show()
plt.plot(sess_data['F3'][400:])
plt.plot(sess_data['F7'][400:])
plt.show()
