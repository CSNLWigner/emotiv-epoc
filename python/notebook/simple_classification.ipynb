# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from math import *
import numpy as np

# %% [markdown]
# ## Mesterséges adat

# %%
def frange(start, stop, lepes):
    lista = []
    x = start
    while x < stop:
        lista.append(x)
        x = x + lepes
    return lista

# %%
eeg_adat = [0.5*(sin(x)+1) for x in frange(0,15,0.1)]

# %%
plt.plot(eeg_adat);

# %%
szemoldok_fent = [int(eeg_adat[i] > 0.9) for i in range(len(adat))]

# %%
plt.plot(eeg_adat)
plt.plot(szemoldok_fent);

# %% [markdown]
# ## Valódi adat

# %%
eeg_adat = np.load("../data/blinking.pkl")
af3 = np.array(eeg_adat["AF3"])[500:1500]
plt.plot(af3);

# %%
def f(adat):
    list = []
    for i in range(len(adat)):
        list.append(int(adat[i] > 0.9))
    return list

# %%
szemoldok_fent = [int(af3[i] > 0.9) for i in range(len(af3))]

# %%
af3=np.array(eeg_adat["AF3"])[300:1250]
plt.plot(af3/100+1)
plt.plot(f(af3));

# %% [markdown]
# ### Időablak osztályozás

# %%
np.mean(eeg_adat)
# Out:
# 0.55929588257659935

# %%
def classify(adat):
    if np.mean(adat) > 0.4:
        return "UP"

# %%
classify(eeg_adat)
# Out:
# 'UP'
