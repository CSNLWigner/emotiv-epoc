# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from math import *
import numpy as np

# %% [markdown]
# ## Mesterséges adat

# %%
def frange(start, stop, lepes):
    lista = []
    x = start
    while x < stop:
        lista.append(x)
        x = x + lepes
    return lista

# %%
eeg_adat = [0.5*(sin(x)+1) for x in frange(0,15,0.1)]

# %%
plt.plot(eeg_adat);

# %%
szemoldok_fent = [int(eeg_adat[i] > 0.9) for i in range(len(adat))]

# %%
plt.plot(eeg_adat)
plt.plot(szemoldok_fent);

# %% [markdown]
# ## Valódi adat

# %%
eeg_adat = np.load()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-f9ef483ffc10> in <module>()
# ----> 1 eeg_adat = np.load()
#
# TypeError: load() missing 1 required positional argument: 'file'

# %% [markdown]
# ### Időablak osztályozás

# %%
np.mean(eeg_adat)
# Out:
# 0.55929588257659935

# %%
def classify(adat):
    if np.mean(adat) > 0.4:
        return "UP"

# %%
classify(eeg_adat)
# Out:
# 'UP'
